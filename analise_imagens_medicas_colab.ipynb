# %% [markdown]
# # MBA FIAP Inteligência Artificial & Machine Learning
#
# ## Visão Computacional: Análise de Imagens Médicas
#
# > Atenção: este notebook foi desenhado para funcionar no **Google Collab**. Se pretende executar localmente prefira a versão local deste notebook, sem o sufixo ```-collab```.
#
#
# ## 1. Introdução
#
# As tecnologias de imagens médicas estão cada vez mais integradas aos sitemas de visão computacional, incluindo as imagens de raio-x.
#
# Modelos de equipamentos modernos geram imagens digitais deste tipo de exame, proporcionando análises mais completas e menos _ad-hoc_, com isso algumas pré-análises podem ser realizadas por aplicações baseadas em inteligência artificial para confirmar ou sugerir diagnósticos ao profissional responsável pelo exame.
#
# No campo dos diagósticos por raios-x, a pnenumonia é uma das enfermidades onde seu uso é um dos mais aplicados para determinar o curso de tratamento.
#
# <p align="center">
#     <img src="https://drive.google.com/uc?id=1TzgzzmOP_KBstZHCv_wbhLkI38lTvRsM"/>
# </p>
#
# ## 2. Instruções
#
# Este projeto final tem como objetivo explorar os conhecimentos adquiridos nas aulas práticas.
#
# Por meio de uma trilha guiada, iremos constuir um modelo que seja capaz de classificar imagens de raio-x para determinar se a determinada pessoa está com alguma condição que necessita maiores cuidados.
#
# De acordo com as imagens disponíveis para o treinamento e validação, será de critério do grupo selecionar as quantidades ideais ou até mesmo pré-processar as imagens para obter o melhor resultado, nos principais indicadores de performance, como precisão, sensibilidade e pontuação F1.
#
# Este projeto poderá ser feita por grupos de até 4 pessoas.
# Caso este projeto seja substitutivo, deverá ser realizado por apenas uma pessoa.
#
# | Nome dos Integrantes     | RM            | Turma |
# | :----------------------- | :------------- | :-----: |
# | Adna Ferreira Maia       | RM 338595     | `14IA` |
# | Giani Betelli Antonello Borges | RM 337632      | `14IA` |
# | Guilherme Csorgo         | RM 338545      | `14IA` |
# | Vitor Stipanich de Santiago | RM 339165      | `14IA` |
#
#
# Por ser um projeto guiado, fique atento quando houver as marcações **Implementação** indica que é necessário realizar alguma implementação em Python no bloco a seguir onde há a inscrição ```##IMPLEMENTAR``` e **Resposta** indica que é esperado uma resposta objetiva relacionado a algum questionamento.
#
# **Cada grupo pode utilizar nas respostas objetivas quaisquer itens necessários que enriqueçam seu ponto vista, como gráficos, fotos e, até mesmo, trechos de código-fonte.**
#
# Pode-se utilizar quantos blocos forem necessários para realizar determinadas implementações ou utilizá-las para justificar as respostas. Não é obrigatório utilizar somente o bloco indicado.
#
# Ao final não se esqueça de subir os arquivos do projeto nas contas do GitHub de cada membro, ou subir na do representante do grupo e os membros realizarem o fork do projeto.
#
# A avaliação terá mais ênfase nos seguintes tópicos de desenvolvimento do projeto:
#
# 1. __Pré-Processamento__
# 2. __Classificação__
# 3. __Performance__
# 4. __Conclusões Finais__

# %% [markdown]
# ## 3.1 Detalhe do problema: a pneunomia
#
# Fonte: [artigo](https://drauziovarella.uol.com.br/doencas-e-sintomas/pneumonia) do Dr. Drauzio Varella.
#
# Pneumonias são infecções que se instalam nos pulmões, órgãos duplos localizados um de cada lado da caixa torácica. Podem acometer a região dos alvéolos pulmonares onde desembocam as ramificações terminais dos brônquios e, às vezes, os interstícios (espaço entre um alvéolo e outro).
#
# Basicamente, pneumonia é provocada pela penetração de um agente infeccioso ou irritante (bactérias, vírus, fungos e por reações alérgicas) no espaço alveolar, onde ocorre a troca gasosa. Esse local deve estar sempre muito limpo, livre de substâncias que possam impedir o contato do ar com o sangue.
#
# Exame clínico, auscultação dos pulmões e radiografias de tórax são recursos essenciais para o diagnóstico de pneumonia.
#
# <p align="center">
#     <img src="https://drive.google.com/uc?id=1btsfr9ib-KplwdV4T5ZweaNvQyRvXLwU">
# </p>

# %% [markdown]
# ## 3.2 Diagnóstico por raio-x

# %% [markdown]
# O exame de raio-x traz diferenças em cada tipo de diagnóstico, sendo considerado os seguintes grupos de análise: **normal** (ou controle) onde não há nenhuma condição de infeção, **bacterial pneumonia** (pneumonia bacteriana) que representa a condição de infecção bacteriana e **viral pneumonia** que indica a condição de infecção vira.

# %% [markdown]
# <p align="center">
# <img src="https://drive.google.com/uc?id=17_JCUsrJtTH-FOOs2EUE2hOBygzDS6V1" height="60%" width="60%">
# </p>

# %% [markdown]
# As imagens de controle não são mais brancas ao centro que é onde fica o coração. Já nas imagens com pneumonia é possível notar regiões brancas ao redor dos pulmões, que é como o exame identifica as secreções responsáveis pela infeçcão.
#
# Quando mais regiões brancas ao redor do pulmão mais severa é a inflamação e menos se observa dos detalhes dos pulmões, ficando um pouco esmaecido diante desta condição.

# %% [markdown]
# ## 4.1 Problema
#
# Construir um classificador utilizando _transfer learning_ para identificar as seguintes classes: **controle**, **pneumonia bacteriana** e **pneumonia viral**.
#
# Para construir este classificador, utilize o dataset do [Kaggle Chest Ray Pneumonia](https://www.kaggle.com/paultimothymooney/chest-xray-pneumonia) e organize os dados de forma a separar em cada uma das classes que já estão definidas no diretório ```raiox```, sendo ```controle``` para as imagens normais (sem inflamação), ```bacteria``` para as imagens de pneumonia bacteriana e ```viral``` para as imagens de pneumonia viral.
#
# Determine a quantidade de imagens a serem treinadas e validadas. Utiliza pelo menos, 100 imagens para cada classe.
#
# Compare os resultados com pelo menos 3 classificadores, obtendo os valores de **precisão (precision)**, **sensibilidade (recall)** e **pontuação F1 (F1 Score)**. No guia abaixo, foi indicado os seguintes modelos: ResNet50, VGG16 e VGG19.
#
# >Importante: a escolha do número de imagens devem ser o suficiente para alcançar o valor de **precisão** mínima de 70%.
# Note que as imagens de pneumonia bacteria e viral estão misturadas dentro da pasta ```PNEUMONIA```. É necessário separar as imagens manualmente tendo como base o sufixo. As imagens que terminal com ```_virus``` se referem a pneumoria viral e as que terminam com ```_bacteria``` se referem a pneumonia bacteriana.
#
# A construção do modelo será utilizada o framework Keras.

# %% [markdown]
# **Pergunta**: Qual o número de imagens que foram selecionadas para cada classe?

# %% [markdown]
# **Resposta**: Pneumonia viral: 1493 - Pneumonia bacteriana: 2780 - Normal: 1583

# %%
import os, os.path
nome_pasta_raiz_imagens = '/content/drive/MyDrive/AI&ML/visão computacional/trabalho-final/analise-imagens-medicas/projeto-final/raiox'

def get_qtde_images(pasta):
  return len([name for name in os.listdir(pasta) if os.path.isfile(os.path.join(pasta, name))])

qtde_pneumonia_viral = get_qtde_images(nome_pasta_raiz_imagens + '/pneumonia_viral')
qtde_pneumonia_bacteriana = get_qtde_images(nome_pasta_raiz_imagens + '/pneumonia_bacteriana') 
qtde_normal = get_qtde_images(nome_pasta_raiz_imagens + '/normal')

print(f'Pneumonia viral: {qtde_pneumonia_viral} - Pneumonia bacteriana: {qtde_pneumonia_bacteriana} - Normal: {qtde_normal}')
# Out:
# Pneumonia viral: 1493 - Pneumonia bacteriana: 2780 - Normal: 1583

# %% [markdown]
# ## 4.2 Componentes obrigatórios
#
# Todas as bibliotecas já estão instaladas no Google Colab.
#
# * Keras
# * Tensorflow
# * Pillow
# * Matplotlib

# %%
import os

import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %matplotlib inline

from tensorflow.keras.models import Sequential, load_model, model_from_json
from tensorflow.keras.layers import Dense, Conv2D, Dropout, Flatten, MaxPooling2D, Activation
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import VGG16, ResNet50, VGG19
from tensorflow.keras.applications.vgg16 import preprocess_input
from tensorflow.keras import Model, layers
from tensorflow.keras import optimizers

import tensorflow.keras.backend as K

# %% [markdown]
# ## 4.3 Carregando imagens de treinamento e validação
#
# Selecione a melhor divisão entre dados de treinamento e validação. O número deverá ser representado em número fracionário, 5% equivale a 0.05, por exemplo.

# %% [markdown]
# > Você pode _montar_ o drive do Google Drive se precisar e quiser armazenar as imagens nesta plataforma. Como o Colab é efêmero, se você copiar os arquivos para o ambiente eles serão apagados depois do fim da sessão. Acesse [esta](https://medium.com/@maxwellcsm/colaboratory-acessando-os-arquivos-do-google-drive-d08ef9157dbf) referência para saber mais como o recurso funciona, inclusive recomenda-se essa abordagem de montar o próprio Google Drive.
#
# Se não for utilizar o Google Drive, crie as pastas que serão utilizadas para armazenar as imagens.

# %% [markdown]
# ### 4.3.1 Utilizando Google Drive
#
# Se usar o Google Drive para armazenar as imagens utilize o comando abaixo para montar seu drive.
# Você pode navegar pelas pastas pelo painel ao lado.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Defina o nome da pasta onde contém as sub-pastas referente aos 3 tipos de classe. Se optar pelo armazenamento efêmero a pasta será ```raiox```. Se optar pelo Goolge Drive, indique o caminho da pasta.

# %%
# # Esse diretório tem o download dos arquivos do Kaggle. Precisamos dividir nas pastas conforme orientado pelo professor!

# path_imagens_kaggle = '/content/drive/MyDrive/AI&ML/visão computacional/trabalho-final/analise-imagens-medicas/projeto-final/kaggle/chest_xray'
# # cada lista armazena o path inteiro da imagem para podermos copiar depois
# healthy_images = []
# virus_images = []
# bacteria_images = []

# def retrieve_files_from(image_dir):
#   result_list = []
#   full_path = f'{path_imagens_kaggle}/{image_dir}'
#   for file in os.listdir(full_path):
#     #filename = os.fsdecode(file)
#     result_list.append(f'{full_path}/{file}')
#   return result_list

# def retrieve_train_test_val(label):
#   result_list = []
#   result_list += retrieve_files_from('train/'+label)
#   result_list += retrieve_files_from('test/'+label)
#   result_list += retrieve_files_from('val/'+label)
#   return result_list


# healthy_images = retrieve_train_test_val('NORMAL')

# for non_healthy in retrieve_train_test_val('PNEUMONIA'):
#   if 'virus' in non_healthy.split('_'):
#     virus_images.append(non_healthy)
#   else:
#     bacteria_images.append(non_healthy)

# print(f'Healthy {len(healthy_images)}')
# print(f'Virus {len(virus_images)}')
# print(f'Bacteria {len(bacteria_images)}')

# # Agora vamos copiar cada arquivo para o seu correspondente diretório
# import shutil
# target_folder = '/content/drive/MyDrive/AI&ML/visão computacional/trabalho-final/analise-imagens-medicas/projeto-final/raiox'
# for image in healthy_images:
#   shutil.copy(image, target_folder+'/normal')
# for image in virus_images:
#   shutil.copy(image, target_folder+'/pneumonia_viral')  
# for image in bacteria_images:
#   shutil.copy(image, target_folder+'/pneumonia_bacteriana')

# %%
## IMPLEMENTE

divisao_treino_validacao = 0.2
nome_pasta_raiz_imagens = '/content/drive/MyDrive/AI&ML/visão computacional/trabalho-final/analise-imagens-medicas/projeto-final/raiox'

# %% [markdown]
# O caminho abaixo da pasta ```raiox``` pode ser alterado caso você opte por utilizar uma pasta específica do seu Google Drive. Neste caso, certifique que dentro delas tem as sub-pastas referentes as imagens normal, pneumonia bacteriana e viral.

# %%
train_datagen = ImageDataGenerator(validation_split=divisao_treino_validacao)

train_generator = train_datagen.flow_from_directory(
    nome_pasta_raiz_imagens,
    batch_size=32,
    class_mode="categorical",
    color_mode="rgb",
    target_size=(224,224),
    subset="training")
# Out:
# Found 4686 images belonging to 3 classes.

# %%
val_generator = train_datagen.flow_from_directory(
    nome_pasta_raiz_imagens,
    batch_size=32,
    class_mode="categorical",
    color_mode="rgb",
    target_size=(224,224),
    subset="validation")
# Out:
# Found 1170 images belonging to 3 classes.

# %%
print(train_generator.class_indices)
print(val_generator.class_indices)
print('---')
print(f'Numero de imagens (teste): {train_generator.samples}')
print(f'Numero de imagens (validacao): {val_generator.samples}')
# Out:
# {'normal': 0, 'pneumonia_bacteriana': 1, 'pneumonia_viral': 2}
# {'normal': 0, 'pneumonia_bacteriana': 1, 'pneumonia_viral': 2}
# ---
# Numero de imagens (teste): 4686
# Numero de imagens (validacao): 1170

# %% [markdown]
# ## 4.4 Modelos de transfer learning
#
# O Keras já possui classes especializadas para os seguintes modelos de deep-learning treinados com o conjunto de dados [ImageNet](http://www.image-net.org/):
#
# * Xception
# * VGG16
# * VGG19
# * ResNet50
# * InceptionV3
# * InceptionResNetV2
# * MobileNet
# * DenseNet
# * NASNet
# * MobileNetV2
#
# Mais detalhes, veja na [documentação do Keras](https://keras.io/applications/).

# %% [markdown]
# Para este estudo, vamos utilizar para avaliação as seguintes arquiteturas: RestNet50, VGG15 e VGG19.

# %% [markdown]
# ## 4.5 Indicadores de desempenho
#
# O Keras não possui os indicadores de desempenho como precisão, sensibilidade e pontuação f1 por padrão, portanto precisamos implementar externamente.

# %%
def recall_score(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def precision_score(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def f1_score(y_true, y_pred):
    precision = precision_score(y_true, y_pred)
    recall = recall_score(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %% [markdown]
# ### 4.5.1 Arquitetura ResNet50

# %% [markdown]
# **Pergunta**: Explique como é constituída a arquitetura do ResNet50? *Utilize, se necessário, gráficos, projetos que utilizam essa arquitetura. Detalhe também sua topologia em camadas e mostre quais as situações essa arquitetura pode ter mais êxito e quais cenários não tem.*

# %% [markdown]
# **Resposta**: A ResNet50 é uma rede neural convolucional que possui 50 camadas de profundidade (por isso o nome). Ela é famosa por se beneficiar de transfer learning, sendo um modelo treinado com mais de 1 milhão de imagens da famosa base de dados ImageNet e é apta de classificar imagens em mais de 1000 classes diferentes. A ResNet é uma rede neural bem grande (quando comparada com as VGG16 e 19, por exemplo), mas o que se destaca é sua arquitetura baseada em "building blocks": os hyperparametros vão sendo ajustados em cada "bloco", composto por diversas camadas (com convoluções, maxpooling, etc).
#
# <p align="center">
# <img src="https://drive.google.com/uc?id=1TshozgQX4Pb9QZv5ZJwWJrm__-Yg5lge" height="60%" width="60%">
# </p>
#
#
#
# <p align="center">
# <img src="https://drive.google.com/uc?id=1zf1CBg4cq_A7rsVSWvi2_1gRm0RN8wwV" height="60%" width="60%">
# </p>

# %% [markdown]
# A técnica de transfer learning consiste de utilizar o mesmo modelo e treiná-lo para outas imagens. Por tal motivo, excluímos a última camada para modelar com as classes que definimos, ou seja, **controle**, **bacteriana** e **viral**.

# %% [markdown]
# Informe a quantidade de classes a serem classificadas.

# %%
## IMPLEMENTE
qtde_classes = 3

# %%
conv_base = ResNet50(include_top=False)

for layer in conv_base.layers:
    layer.trainable = False
# Out:
# ...
# 94773248/94765736 [==============================] - 1s 0us/step

# %%
x = conv_base.output
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(128, activation='relu')(x) 

predictions = layers.Dense(qtde_classes, activation='softmax')(x)
print(conv_base.input.shape)
model = Model(conv_base.input, predictions)

model.summary()
# Out:
# (None, None, None, 3)
# Model: "model_13"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_12 (InputLayer)           [(None, None, None,  0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, None, None, 3 0           input_12[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, None, None, 6 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, None, None, 6 256         conv1_conv[0][0]
# __________________________________________________________________________________________________
# ...

# %%
optimizer = optimizers.Adam()
model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=[precision_score, recall_score, f1_score])

# %% [markdown]
# O número de épocas define quantas vezes o modelo irá treinar e validar o erro, assim ajustando os pesos para melhor convergência.
# Escolha o número adequado de épocas para alcançarmos pelo menos **70% de precisão de validação**.

# %%
## IMPLEMENTE
qtde_epocas = 15

# %%
history = model.fit(train_generator, epochs=qtde_epocas, validation_steps=5, steps_per_epoch=5, 
                    validation_data=val_generator)
# Out:
# Epoch 1/15
# 5/5 [==============================] - 65s 13s/step - loss: 1.8128 - precision_score: 0.4609 - recall_score: 0.4285 - f1_score: 0.4436 - val_loss: 1.1728 - val_precision_score: 0.5382 - val_recall_score: 0.4750 - val_f1_score: 0.5039
# Epoch 2/15
# 5/5 [==============================] - 57s 12s/step - loss: 0.8131 - precision_score: 0.6935 - recall_score: 0.6305 - f1_score: 0.6599 - val_loss: 0.8692 - val_precision_score: 0.6702 - val_recall_score: 0.6187 - val_f1_score: 0.6433
# Epoch 3/15
# 5/5 [==============================] - 57s 12s/step - loss: 0.6234 - precision_score: 0.7758 - recall_score: 0.7156 - f1_score: 0.7439 - val_loss: 0.6130 - val_precision_score: 0.7864 - val_recall_score: 0.7375 - val_f1_score: 0.7609
# Epoch 4/15
# 5/5 [==============================] - 56s 12s/step - loss: 0.6231 - precision_score: 0.7789 - recall_score: 0.7320 - f1_score: 0.7542 - val_loss: 0.5990 - val_precision_score: 0.7732 - val_recall_score: 0.7250 - val_f1_score: 0.7483
# ...

# %% [markdown]
# Um modelo que converge bem possui o gráfico de perda (*loss*) descendente e os gráfico de precisão (*precision*), sensibilidade (*recall*) e pontuação f1 (*f1 score*) em acendente.

# %%
# Exibindo dados de Precisão
plt.plot(history.history['precision_score'])
plt.plot(history.history['val_precision_score'])
plt.title('model precision')
plt.ylabel('precision')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Exibindo dados de Sensibilidade
plt.plot(history.history['recall_score'])
plt.plot(history.history['val_recall_score'])
plt.title('model recall')
plt.ylabel('recall')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Exibindo dados de F1 Score
plt.plot(history.history['f1_score'])
plt.plot(history.history['val_f1_score'])
plt.title('model f1_score')
plt.ylabel('f1_score')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Exibindo dados de Perda
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# **Pergunta**: Avalie os gráficos de perda (*loss*), precisão (*precision*), sensibilidade (*recall*) e pontuação f1 (*f1 score*)  e explique o comportamento de ambos no que tange a convergência do modelo.

# %% [markdown]
# **Resposta**:
#
# No gráfico de **loss**, quando comparamos o início do treino e o início do teste, os valores são bem distantes e vão convergindo ao longo da execução das épocas. Como a RESNET50 é baseada em building blocks, os hiperparametros são ajustados ao longo do tempo em cada bloco, o que condiz com a convergência do modelo ao passar das épocas.
#
#
# O gráfico de **precision** começa baixíssimo, o que é esperado já que a rede é treinada em imagens de diversas categorias diferentes. Com o passar das épocas, ao apresentar imagens de raio-x para o modelo, os parâmetros vão sendo ajustados da maneira correta e a precisão vai aumentando de maneira gradual

# %% [markdown]
# **Pergunta**: Quais são os valores de **precisão (precision)**, **sensibilidade (recall)** de validação?
#
# *Estes valores são exibidos durante o treinamento, utilize a última saída, exemplo:*
#
# ```
# Epoch 10/10 [==============================] - 45s 9s/step - loss: 0.1234 - precision_score: 0.9742 - recall_score: 0.9683 - f1_score: 0.9712 - val_loss: 0.8819 - val_precision_score: 0.6912 - val_recall_score: 0.5649 - val_f1_score: 0.6216```
#
# No caso acima, o valor de precisão, sensibilidade e pontuação de validação são, respectivamente, 69,12%, 56,49% e 62,16%.

# %% [markdown]
# **Resposta**:
#
#
#
# Precisão: 79,81%
#
# Sensibilidade: 75,63%
#
# Pontuação de validação: 77,64%

# %% [markdown]
# ### 4.5.2 Arquitetura VGG16

# %% [markdown]
# **Pergunta**: Explique como é constituída a arquitetura do VGG16? *Utilize, se necessário, gráficos, projetos que utilizam essa arquitetura. Detalhe também sua topologia em camadas e mostre quais as situações essa arquitetura pode ter mais êxito e quais cenários não tem.*

# %% [markdown]
# **Resposta**: VGG16 é outra rede neural convolucional muito famosa pelo seu forte potencial de classificação de imagens. A rede se destacou em 2014 por ter uma arquitetura diferenciada - ela tem diversas camadas convolucionais usando kernels 3x3 e 1 de stride (com padding constante). Isso denota uma característica específica das VGG: o foco em ter convoluções constantes, e ir "afunilando" as camada utilizando maxpooling.
#
#
#
# <p align="center">
# <img src="https://drive.google.com/uc?id=1SToOXtZmTlpMiMzv6BHQh1TbmwMNSjVu" height="60%" width="60%">
# </p>

# %%
conv_base = VGG16(include_top=False)

for layer in conv_base.layers:
    layer.trainable = False

# %%
x = conv_base.output
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(128, activation='relu')(x) 

predictions = layers.Dense(qtde_classes, activation='softmax')(x)
print(conv_base.input.shape)
model = Model(conv_base.input, predictions)

model.summary()
# Out:
# (None, None, None, 3)
# Model: "model_14"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_13 (InputLayer)        [(None, None, None, 3)]   0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, None, None, 64)    1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, None, None, 64)    36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, None, None, 64)    0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, None, None, 128)   73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, None, None, 128)   147584
# _________________________________________________________________
# ...

# %%
optimizer = optimizers.Adam()
model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=[precision_score, recall_score, f1_score])

# %%
history = model.fit(train_generator, epochs=qtde_epocas, validation_steps=5, steps_per_epoch=5, 
                    validation_data=val_generator)
# Out:
# Epoch 1/15
# 5/5 [==============================] - 173s 37s/step - loss: 3.9982 - precision_score: 0.2154 - recall_score: 0.2091 - f1_score: 0.2122 - val_loss: 1.4122 - val_precision_score: 0.5456 - val_recall_score: 0.5188 - val_f1_score: 0.5317
# Epoch 2/15
# 5/5 [==============================] - 164s 36s/step - loss: 1.3659 - precision_score: 0.5495 - recall_score: 0.5240 - f1_score: 0.5362 - val_loss: 1.3946 - val_precision_score: 0.4845 - val_recall_score: 0.4750 - val_f1_score: 0.4796
# Epoch 3/15
# 5/5 [==============================] - 163s 36s/step - loss: 1.0418 - precision_score: 0.6504 - recall_score: 0.6314 - f1_score: 0.6406 - val_loss: 1.1135 - val_precision_score: 0.7028 - val_recall_score: 0.6938 - val_f1_score: 0.6982
# Epoch 4/15
# 5/5 [==============================] - 168s 37s/step - loss: 1.0070 - precision_score: 0.7349 - recall_score: 0.7019 - f1_score: 0.7179 - val_loss: 0.8273 - val_precision_score: 0.7466 - val_recall_score: 0.7188 - val_f1_score: 0.7320
# ...

# %% [markdown]
# Um modelo que converge bem possui o gráfico de perda (*loss*) descendente e os gráfico de precisão (*precision*), sensibilidade (*recall*) e pontuação f1 (*f1 score*) em acendente.

# %%
# Exibindo dados de Precisão
plt.plot(history.history['precision_score'])
plt.plot(history.history['val_precision_score'])
plt.title('model precision')
plt.ylabel('precision')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Exibindo dados de Sensibilidade
plt.plot(history.history['recall_score'])
plt.plot(history.history['val_recall_score'])
plt.title('model recall')
plt.ylabel('recall')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Exibindo dados de F1 Score
plt.plot(history.history['f1_score'])
plt.plot(history.history['val_f1_score'])
plt.title('model f1_score')
plt.ylabel('f1_score')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Exibindo dados de Perda
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# **Pergunta**: Avalie os gráficos de perda (*loss*), precisão (*precision*), sensibilidade (*recall*) e pontuação f1 (*f1 score*)  e explique o comportamento de ambos no que tange a convergência do modelo.

# %% [markdown]
# **Resposta**:
#
# Os gráficos de loss e precision estão convergindo da maneira esperada (loss descendente e precision ascendente).

# %% [markdown]
# **Pergunta**: Quais são os valores de **precisão (precision)**, **sensibilidade (recall)** de validação?
#
# *Estes valores são exibidos durante o treinamento, utilize a última saída, exemplo:*
#
# ```
# Epoch 10/10 [==============================] - 45s 9s/step - loss: 0.1234 - precision_score: 0.9742 - recall_score: 0.9683 - f1_score: 0.9712 - val_loss: 0.8819 - val_precision_score: 0.6912 - val_recall_score: 0.5649 - val_f1_score: 0.6216```
#
# No caso acima, o valor de precisão, sensibilidade e pontuação de validação são, respectivamente, 69,12%, 56,49% e 62,16%.

# %% [markdown]
# **Resposta**:
#
#
# Precisão: 75,34%
#
# Sensibilidade: 73,75%
#
# Pontuação de validação: 74,52%

# %% [markdown]
# ### 4.5.3 Arquitetura VGG19

# %% [markdown]
# **Pergunta**: Explique como é constituída a arquitetura do VGG19? *Utilize, se necessário, gráficos, projetos que utilizam essa arquitetura. Detalhe também sua topologia em camadas e mostre quais as situações essa arquitetura pode ter mais êxito e quais cenários não tem.*

# %% [markdown]
# **Resposta**: A VGG19 é outra variante do modelo VGG, assim como a VGG16, com apenas algumas camadas convolucionais a mais, sendo 16 camadas convolucionais e 3 camadas conectadas.
#
#
# <p align="center">
# <img src="https://drive.google.com/uc?id=1MsMpvNIbnfO8XZ5k8Ga6p9ZZjmdQiaC0" height="60%" width="60%">
# </p>

# %%
conv_base = VGG19(include_top=False)

for layer in conv_base.layers:
    layer.trainable = False
# Out:
# ...
# 80142336/80134624 [==============================] - 1s 0us/step

# %%
x = conv_base.output
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(128, activation='relu')(x) 

predictions = layers.Dense(qtde_classes, activation='softmax')(x)
model = Model(conv_base.input, predictions)

model.summary()
# Out:
# Model: "model_15"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_14 (InputLayer)        [(None, None, None, 3)]   0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, None, None, 64)    1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, None, None, 64)    36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, None, None, 64)    0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, None, None, 128)   73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, None, None, 128)   147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, None, None, 128)   0
# ...

# %%
optimizer = optimizers.Adam()
model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=[precision_score, recall_score, f1_score])

# %%
history = model.fit(train_generator, epochs=qtde_epocas, validation_steps=5, steps_per_epoch=5, 
                    validation_data=val_generator)
# Out:
# Epoch 1/15
# 5/5 [==============================] - 190s 42s/step - loss: 4.1683 - precision_score: 0.4418 - recall_score: 0.4391 - f1_score: 0.4404 - val_loss: 2.8389 - val_precision_score: 0.3626 - val_recall_score: 0.3562 - val_f1_score: 0.3594
# Epoch 2/15
# 5/5 [==============================] - 199s 45s/step - loss: 2.8271 - precision_score: 0.3602 - recall_score: 0.3464 - f1_score: 0.3531 - val_loss: 1.8826 - val_precision_score: 0.5375 - val_recall_score: 0.5375 - val_f1_score: 0.5375
# Epoch 3/15
# 5/5 [==============================] - 192s 43s/step - loss: 2.3942 - precision_score: 0.4726 - recall_score: 0.4615 - f1_score: 0.4668 - val_loss: 1.5765 - val_precision_score: 0.5303 - val_recall_score: 0.5000 - val_f1_score: 0.5144
# Epoch 4/15
# 5/5 [==============================] - 187s 42s/step - loss: 1.4399 - precision_score: 0.5400 - recall_score: 0.5017 - f1_score: 0.5201 - val_loss: 0.9429 - val_precision_score: 0.6676 - val_recall_score: 0.6562 - val_f1_score: 0.6618
# ...

# %% [markdown]
# Um modelo que converge bem possui o gráfico de perda (*loss*) descendente e os gráfico de precisão (*precision*), sensibilidade (*recall*) e pontuação f1 (*f1 score*) em acendente.

# %%
# Exibindo dados de Precisão
plt.plot(history.history['precision_score'])
plt.plot(history.history['val_precision_score'])
plt.title('model precision')
plt.ylabel('precision')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Exibindo dados de Sensibilidade
plt.plot(history.history['recall_score'])
plt.plot(history.history['val_recall_score'])
plt.title('model recall')
plt.ylabel('recall')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Exibindo dados de F1 Score
plt.plot(history.history['f1_score'])
plt.plot(history.history['val_f1_score'])
plt.title('model f1_score')
plt.ylabel('f1_score')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Exibindo dados de Perda
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# **Pergunta**: Avalie os gráficos de perda (*loss*), precisão (*precision*), sensibilidade (*recall*) e pontuação f1 (*f1 score*)  e explique o comportamento de ambos no que tange a convergência do modelo.

# %% [markdown]
# **Resposta**:

# %% [markdown]
# **Pergunta**: Quais são os valores de **precisão (precision)**, **sensibilidade (recall)** de validação?
#
# *Estes valores são exibidos durante o treinamento, utilize a última saída, exemplo:*
#
# ```
# Epoch 10/10 [==============================] - 45s 9s/step - loss: 0.1234 - precision_score: 0.9742 - recall_score: 0.9683 - f1_score: 0.9712 - val_loss: 0.8819 - val_precision_score: 0.6912 - val_recall_score: 0.5649 - val_f1_score: 0.6216```
#
# No caso acima, o valor de precisão, sensibilidade e pontuação de validação são, respectivamente, 69,12%, 56,49% e 62,16%.

# %% [markdown]
# **Resposta**:
#
#
# Precisão: 81,74%
#
# Sensibilidade: 78,75%
#
# Pontuação de validação: 80,19%

# %% [markdown]
# ## 4.6 Compartivo de arquiteturas
#
# Preencha a tabela abaixo com os valores dos indicadores de performance apresentados.
#
# _O cálculo do F1-Score é dado por 2 * (Precisão * Sensibilidade) / (Precisão + Sensibilidade)._

# %% [markdown]
# | Modelo   | Precisão (*Precision*) | Sensibilidade (*Recall*) | F1-Score |
# |----------|----------|---------------|----------|
# | ResNet50 | 79,81%     | 75,63%          | 77,64%     |
# | VGG16    | 75,34%     | 73,75%          | 74,52%     |
# | VGG19    | 81,74%     | 78,75%          | 80,19%     |

# %% [markdown]
# ## 4.7 Conclusões
#
# Analise os resultados da tabela de indicadores do comparativo de arquiteturas e explique os principais motivos pelos quais cada modelo obteve cada resultado.

# %% [markdown]
# **Resposta**:
#
# Mesmo tendo uma arquitetura menos robusta quando comparado à ResNet50, a VGG19 obteve resultados significantemente melhores e, conforme visto em aula, isso é esperado visto que é uma arquitetura mais recente quando comparada à ResNet.

# %% [markdown]
# ## 4.8 Abordagem adicional (obrigatório)
#
# Considerando os outros classificadores, escolha outro que ainda não foi utilizado, implemente abaixo. Ao final compare os resultados e explique os resultados.
#
# _Não se esquece de utilizar as importações adequadas para cada modelo.
# A forma de implementação deve respeitar as mesmas condições como valor de split e quantidade de imagens para poder comparar os modelos._

# %%
# REDE ESCOLHIDA: INCEPTION
from keras.models import Model
from keras.layers import Input
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers.merge import concatenate
from keras.utils import plot_model
 
# function for creating a naive inception block
def naive_inception_module(layer_in):
  conv1 = Conv2D(64, (1,1), padding='same', activation='relu')(layer_in)
  conv3 = Conv2D(128, (3,3), padding='same', activation='relu')(layer_in)
  conv5 = Conv2D(32, (5,5), padding='same', activation='relu')(layer_in)
  pool = MaxPooling2D((3,3), strides=(1,1), padding='same')(layer_in)  
  conc = concatenate([conv1, conv3, conv5, pool], axis=-1)  

  avg_pool = layers.GlobalAveragePooling2D()(conc)
  classes = layers.Dense(128, activation='relu')(avg_pool) 
  predictions = layers.Dense(qtde_classes, activation='softmax')(classes)
  return predictions
 
# define model input
qtde_classes = 3
visible = Input(shape=(224, 224, 3))
inception = naive_inception_module(visible)

model = Model(inputs=visible, outputs=inception)
#model.summary()
plot_model(model, show_shapes=True)

# %%
qtde_epocas = 15

optimizer = optimizers.Adam()
model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=[precision_score, recall_score, f1_score])

history = model.fit(train_generator, 
                    epochs=qtde_epocas, 
                    validation_steps=5, 
                    steps_per_epoch=5, 
                    validation_data=val_generator)
# Out:
# Epoch 1/15
# 5/5 [==============================] - 180s 39s/step - loss: 3.3467 - precision_score: 0.4019 - recall_score: 0.3873 - f1_score: 0.3942 - val_loss: 2.4045 - val_precision_score: 0.4216 - val_recall_score: 0.4187 - val_f1_score: 0.4201
# Epoch 2/15
# 5/5 [==============================] - 175s 38s/step - loss: 1.5008 - precision_score: 0.5472 - recall_score: 0.5245 - f1_score: 0.5355 - val_loss: 1.4249 - val_precision_score: 0.6928 - val_recall_score: 0.6812 - val_f1_score: 0.6869
# Epoch 3/15
# 5/5 [==============================] - 176s 38s/step - loss: 1.1166 - precision_score: 0.6896 - recall_score: 0.6465 - f1_score: 0.6671 - val_loss: 1.1774 - val_precision_score: 0.6519 - val_recall_score: 0.6313 - val_f1_score: 0.6413
# Epoch 4/15
# 5/5 [==============================] - 174s 38s/step - loss: 1.0873 - precision_score: 0.6791 - recall_score: 0.6580 - f1_score: 0.6682 - val_loss: 1.0432 - val_precision_score: 0.6739 - val_recall_score: 0.6562 - val_f1_score: 0.6649
# ...

# %%
# Exibindo dados de Precisão
plt.plot(history.history['precision_score'])
plt.plot(history.history['val_precision_score'])
plt.title('model precision')
plt.ylabel('precision')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Exibindo dados de Sensibilidade
plt.plot(history.history['recall_score'])
plt.plot(history.history['val_recall_score'])
plt.title('model recall')
plt.ylabel('recall')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Exibindo dados de F1 Score
plt.plot(history.history['f1_score'])
plt.plot(history.history['val_f1_score'])
plt.title('model f1_score')
plt.ylabel('f1_score')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Exibindo dados de Perda
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# ### 4.8.1 Conclusões sobre a abordagem adicional
#
# Como seu modelo performou em comparação com os demais modelos anteriores? Justifique sua resposta levando em consideração a arquitetura respectiva.

# %% [markdown]
# **Resposta**:
#
#
# Precisão: 75,32%
#
# Sensibilidade: 74,37%
#
# Pontuação de validação: 74,84%
#
#
# O modelo escolhido para a abordagem extra foi o Inception. Ele foi proposto em 2015, e seu grande diferencial é o chamado "**inception module**"; um bloco de **convolução em paralelo** com kernels distintos (1, 3 e 5) e um maxpooling para concatenar os resultados no final. A implementação feita acima foi rápida e simples, apenas para demonstrar o grande diferencial do modelo (camadas em paralelo). Essa implementação, conhecida também como naive inception, é bem simples e serve de base para entendimento do modelo. Com um poder computacional maior, podemos adicionar mais inception modules em nossa rede para poder experimentar com resultados diferentes.
# Com os resultados acima podemos concluir que o modelo não ganhou um destaque quando comparado ao VGG e à ResNet, mas obteve resultados semelhantes!
